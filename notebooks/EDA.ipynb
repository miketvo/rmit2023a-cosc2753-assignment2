# %% [markdown]
# # I. Exploratory Data Analysis
#
# [//]: # (TODO: Write methodology and observations here)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from utils import dataset
from utils.glob import COLORS


plt.style.use('ggplot')

# %%
df = dataset.load()

# %%
df.describe()
# Out:
#                 ImgPath       Class
# count              4928        4928
# unique             4928           8
# top     Baby/baby_1.jpg  Lisianthus
# freq                  1         969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4928 entries, 0 to 4927
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ImgPath  4928 non-null   object
#  1   Class    4928 non-null   object
# dtypes: object(2)
# memory usage: 77.1+ KB

# %%
df.sample(n=42, random_state=42)
# Out:
#                                   ImgPath          Class
# 1665  Chrysanthemum/chrysanthemum_442.jpg  Chrysanthemum
# 3592            Pingpong/pingpong_211.jpg       Pingpong
# 2726        Lisianthus/lisianthus_304.jpg     Lisianthus
# 2380         Hydrangeas/hydrangeas_46.jpg     Hydrangeas
# 676                     Baby/baby_708.jpg           Baby
# 290                     Baby/baby_360.jpg           Baby
# 577                     Baby/baby_619.jpg           Baby
# 2561        Lisianthus/lisianthus_156.jpg     Lisianthus
# 1519  Chrysanthemum/chrysanthemum_310.jpg  Chrysanthemum
# 2194        Hydrangeas/hydrangeas_292.jpg     Hydrangeas
# 2580        Lisianthus/lisianthus_173.jpg     Lisianthus
# 1926  Chrysanthemum/chrysanthemum_678.jpg  Chrysanthemum
# 4210                    Tana/tana_290.jpg           Tana
# 2331        Hydrangeas/hydrangeas_415.jpg     Hydrangeas
# 1175           Calimerio/calimero_318.jpg      Calimerio
# 1321  Chrysanthemum/chrysanthemum_132.jpg  Chrysanthemum
# 3819             Pingpong/pingpong_92.jpg       Pingpong
# 1020           Calimerio/calimero_179.jpg      Calimerio
# 2833        Lisianthus/lisianthus_400.jpg     Lisianthus
# 373                     Baby/baby_435.jpg           Baby
# 1025           Calimerio/calimero_183.jpg      Calimerio
# 151                     Baby/baby_235.jpg           Baby
# 3131         Lisianthus/lisianthus_67.jpg     Lisianthus
# 2025         Hydrangeas/hydrangeas_14.jpg     Hydrangeas
# 1090           Calimerio/calimero_241.jpg      Calimerio
# 1862   Chrysanthemum/chrysanthemum_62.jpg  Chrysanthemum
# 3496            Pingpong/pingpong_125.jpg       Pingpong
# 841                     Baby/baby_857.jpg           Baby
# 4128                    Tana/tana_216.jpg           Tana
# 1041           Calimerio/calimero_198.jpg      Calimerio
# 530                     Baby/baby_577.jpg           Baby
# 1504  Chrysanthemum/chrysanthemum_298.jpg  Chrysanthemum
# 3529            Pingpong/pingpong_155.jpg       Pingpong
# 2072        Hydrangeas/hydrangeas_182.jpg     Hydrangeas
# 2111        Hydrangeas/hydrangeas_217.jpg     Hydrangeas
# 4834             Tana/tana_scrape2_83.jpg           Tana
# 248                     Baby/baby_322.jpg           Baby
# 2119        Hydrangeas/hydrangeas_224.jpg     Hydrangeas
# 4316                    Tana/tana_386.jpg           Tana
# 2820         Lisianthus/lisianthus_39.jpg     Lisianthus
# 4903              Tana/tana_scrape3_7.jpg           Tana
# 4803             Tana/tana_scrape2_56.png           Tana

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

sns.histplot(df, x='Class', ax=ax)
ax.set_xticks(ax.get_xticks())
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title('Flower Classes Sample Count')

for i, p in enumerate(ax.patches):
    ax.annotate(
        str(p.get_height()),
        (p.get_x() + p.get_width() / 2.,
         p.get_height()),
        ha='center', va='center', xytext=(0, 5), textcoords='offset points'
    )
    p.set_facecolor(COLORS[i])

plt.show()
fig.savefig('images/EDA-Class-Dist.png')
