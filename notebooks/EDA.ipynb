# %% [markdown]
# # I. Exploratory Data Analysis
#
# [//]: # (TODO: Write methodology and observations here)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from utils import dataset
from utils.glob import COLORS


plt.style.use('ggplot')

# %%
df = dataset.load()

# %%
df.describe()
# Out:
#                 ImgPath       Class
# count              4621        4621
# unique             4621           8
# top     Baby/baby_1.jpg  Lisianthus
# freq                  1         969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4621 entries, 0 to 4620
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ImgPath  4621 non-null   object
#  1   Class    4621 non-null   object
# dtypes: object(2)
# memory usage: 72.3+ KB

# %%
df.sample(n=42, random_state=42)
# Out:
#                                   ImgPath          Class
# 3940                     Rosy/rosy_47.jpg           Rosy
# 478                      Baby/baby_53.jpg           Baby
# 561                     Baby/baby_604.jpg           Baby
# 2603        Lisianthus/lisianthus_194.jpg     Lisianthus
# 2867        Lisianthus/lisianthus_431.jpg     Lisianthus
# 3003        Lisianthus/lisianthus_554.jpg     Lisianthus
# 3549            Pingpong/pingpong_173.jpg       Pingpong
# 4550                    Tana/tana_597.jpg           Tana
# 3089        Lisianthus/lisianthus_631.jpg     Lisianthus
# 240                     Baby/baby_315.jpg           Baby
# 3869                    Rosy/rosy_137.jpg           Rosy
# 416                     Baby/baby_474.jpg           Baby
# 3150        Lisianthus/lisianthus_687.jpg     Lisianthus
# 23                       Baby/baby_12.jpg           Baby
# 931              Calimerio/calimero_0.jpg      Calimerio
# 2988        Lisianthus/lisianthus_540.jpg     Lisianthus
# 4293                    Tana/tana_365.jpg           Tana
# 2168        Hydrangeas/hydrangeas_269.jpg     Hydrangeas
# 3341        Lisianthus/lisianthus_859.jpg     Lisianthus
# 2493         Hydrangeas/hydrangeas_95.jpg     Hydrangeas
# 1158           Calimerio/calimero_302.jpg      Calimerio
# 4574                    Tana/tana_618.jpg           Tana
# 1180           Calimerio/calimero_322.jpg      Calimerio
# 1427  Chrysanthemum/chrysanthemum_228.jpg  Chrysanthemum
# 534                     Baby/baby_580.jpg           Baby
# 387                     Baby/baby_448.jpg           Baby
# 787                     Baby/baby_808.jpg           Baby
# 776                     Baby/baby_799.jpg           Baby
# 2855        Lisianthus/lisianthus_420.jpg     Lisianthus
# 3456        Lisianthus/lisianthus_962.jpg     Lisianthus
# 33                      Baby/baby_129.jpg           Baby
# 1558  Chrysanthemum/chrysanthemum_346.jpg  Chrysanthemum
# 4101                    Tana/tana_192.jpg           Tana
# 2179        Hydrangeas/hydrangeas_279.jpg     Hydrangeas
# 26                      Baby/baby_122.jpg           Baby
# 3166        Lisianthus/lisianthus_700.jpg     Lisianthus
# 999             Calimerio/calimero_16.jpg      Calimerio
# 3725            Pingpong/pingpong_331.jpg       Pingpong
# 3947                     Rosy/rosy_53.jpg           Rosy
# 230                     Baby/baby_306.jpg           Baby
# 1438  Chrysanthemum/chrysanthemum_238.jpg  Chrysanthemum
# 3410        Lisianthus/lisianthus_920.jpg     Lisianthus

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

sns.histplot(df, x='Class', ax=ax)
ax.set_xticks(ax.get_xticks())
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title('Flower Classes Sample Count')

for i, p in enumerate(ax.patches):
    ax.annotate(
        str(p.get_height()),
        (p.get_x() + p.get_width() / 2.,
         p.get_height()),
        ha='center', va='center', xytext=(0, 5), textcoords='offset points'
    )
    p.set_facecolor(COLORS[i])

plt.show()
fig.savefig('images/EDA-Class-Dist.png')
