# %% [markdown]
# # I. Exploratory Data Analysis
#
# [//]: # (TODO: Write methodology and observations here)

# %%
import matplotlib.pyplot as plt
from PIL import Image

from utils import dataset
from utils.visualization import plot_class_distribution


plt.style.use('ggplot')

# %%
df_raw = dataset.load('../data/raw')

# %%
df_raw.describe()
# Out:
#                 ImgPath       Class
# count             16362       16362
# unique            16362           8
# top     Baby/000001.jpg  Lisianthus
# freq                  1        2090

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16362 entries, 0 to 16361
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ImgPath  16362 non-null  object
#  1   Class    16362 non-null  object
# dtypes: object(2)
# memory usage: 255.8+ KB

# %%
df_raw.sample(n=42, random_state=42)
# Out:
#                                    ImgPath          Class
# 5379              Chrysanthemum/001293.jpg  Chrysanthemum
# 6176                 Hydrangeas/000026.jpg     Hydrangeas
# 10769                  Pingpong/000481.jpg       Pingpong
# 7593                 Hydrangeas/001443.jpg     Hydrangeas
# 10662                  Pingpong/000374.jpg       Pingpong
# 2087                  Calimerio/000026.jpg      Calimerio
# 123                        Baby/000124.jpg           Baby
# 8962                 Lisianthus/000764.jpg     Lisianthus
# 10010        Lisianthus/lisianthus_720.jpg     Lisianthus
# 8419                 Lisianthus/000221.jpg     Lisianthus
# 6486                 Hydrangeas/000336.jpg     Hydrangeas
# 7182                 Hydrangeas/001032.jpg     Hydrangeas
# 3204                  Calimerio/001143.jpg      Calimerio
# 6576                 Hydrangeas/000426.jpg     Hydrangeas
# 3322                  Calimerio/001261.jpg      Calimerio
# ...

# %%
plot_class_distribution(df_raw, 'Flower Classes Distribution', to_file='images/EDA-Class-Dist.png')
