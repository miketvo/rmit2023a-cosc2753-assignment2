# %% [markdown]
# # Step 3. Flower Classifier - Baseline Model
#
# This is a simple Artificial Neural Network with 4 hidden layers.
#
# Optimizer: `tf.keras.optimizers.Adam`
#
# According to [Tensorflow API docs](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam), Adam optimization is a stochastic gradient descent method based on adaptive estimation of first-order and second-order moments. This method is "computationally efficient, has little memory requirement, invariant to diagonal rescaling of gradients, and is well suited for problems that are large in terms of data/parameters". Thus, this is the perfect fit for our task of image classification, since we will generate a large amount of trainable parameters that has large computing power requirement that we aim to minimize while still ensuring our model's performance.
#
# Since our data is balanced, the metric we are using to evaluate its performance is **Accuracy** ($Accuracy = \frac{correct \; classifications}{all \; classifications}$), more specifically its [Tensorflow's CategoricalAccuracy Implementation](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/CategoricalAccuracy).
#
# Refer to the code below to see how it is set up, trained, and evaluated.

# %%
# Imports and environmental setups

import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam


# Custom utils functions
from utils import dataset
from utils.visualization import plot_learning_curve
from utils.visualization import visualize_predictions
from utils.glob import TARGET_IMG_SIZE


plt.style.use('ggplot')
model_name = 'clf-baseline'
dir_raw_dataset = '../data/raw/'
dir_train_dataset = '../data/train/'
dir_test_dataset = '../data/test/'
dir_log = '../log/' + model_name
dir_models = '../models/'
path_model = dir_models + model_name

# %% [markdown]
# ## 3.1. Load Dataset

# %%
df = dataset.load(dir_train_dataset)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13073 entries, 0 to 13072
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ImgPath       13073 non-null  object
#  1   FileType      13073 non-null  object
#  2   Width         13073 non-null  int64
#  3   Height        13073 non-null  int64
#  4   Ratio         13073 non-null  float64
#  5   Mode          13073 non-null  object
#  6   Bands         13073 non-null  object
#  7   Transparency  13073 non-null  bool
#  8   Animated      13073 non-null  bool
#  9   Class         13073 non-null  object
# dtypes: bool(2), float64(1), int64(2), object(5)
# memory usage: 842.7+ KB

# %%
df.sample(n=42, random_state=42)
# Out:
#                              ImgPath FileType  Width  Height  Ratio Mode
# 10022                Rosy/000274.jpg      jpg    512     512    1.0  RGB  \
# 11756                Tana/000414.jpg      jpg    512     512    1.0  RGB
# 12394                Tana/001211.jpg      jpg    512     512    1.0  RGB
# 11387               Rosy/rosy_60.jpg      jpg    512     512    1.0  RGB
# 7551   Lisianthus/lisianthus_247.jpg      jpg    512     512    1.0  RGB
# 6202   Hydrangeas/hydrangeas_187.jpg      jpg    512     512    1.0  RGB
# 5714           Hydrangeas/001008.jpg      jpg    512     512    1.0  RGB
# 7990   Lisianthus/lisianthus_761.jpg      jpg    512     512    1.0  RGB
# 12896              Tana/tana_458.jpg      jpg    512     512    1.0  RGB
# 3288        Chrysanthemum/000005.jpg      jpg    512     512    1.0  RGB
# 749                  Baby/000941.jpg      jpg    512     512    1.0  RGB
# 10619                Rosy/001019.jpg      jpg    512     512    1.0  RGB
# 3706        Chrysanthemum/000539.jpg      jpg    512     512    1.0  RGB
# 7814   Lisianthus/lisianthus_555.jpg      jpg    512     512    1.0  RGB
# 4982           Hydrangeas/000104.jpg      jpg    512     512    1.0  RGB
# 7923    Lisianthus/lisianthus_69.jpg      jpg    512     512    1.0  RGB
# 2264            Calimerio/000745.jpg      jpg    512     512    1.0  RGB
# 7770   Lisianthus/lisianthus_502.jpg      jpg    512     512    1.0  RGB
# 10129                Rosy/000402.jpg      jpg    512     512    1.0  RGB
# 7104           Lisianthus/000718.jpg      jpg    512     512    1.0  RGB
# 5561           Hydrangeas/000821.jpg      jpg    512     512    1.0  RGB
# 1217               Baby/baby_439.jpg      jpg    512     512    1.0  RGB
# 4238        Chrysanthemum/001227.jpg      jpg    512     512    1.0  RGB
# 11720                Tana/000372.jpg      jpg    512     512    1.0  RGB
# 2201            Calimerio/000670.jpg      jpg    512     512    1.0  RGB
# 12093                Tana/000834.jpg      jpg    512     512    1.0  RGB
# 9609       Pingpong/pingpong_210.jpg      jpg    512     512    1.0  RGB
# 7047           Lisianthus/000648.jpg      jpg    512     512    1.0  RGB
# 7550   Lisianthus/lisianthus_246.jpg      jpg    512     512    1.0  RGB
# 1662               Baby/baby_922.jpg      jpg    512     512    1.0  RGB
# 8992             Pingpong/001006.jpg      jpg    512     512    1.0  RGB
# 7030           Lisianthus/000630.jpg      jpg    512     512    1.0  RGB
# 99                   Baby/000131.jpg      jpg    512     512    1.0  RGB
# 9393             Pingpong/001512.jpg      jpg    512     512    1.0  RGB
# 11535                Tana/000146.jpg      jpg    512     512    1.0  RGB
# 12714              Tana/tana_255.jpg      jpg    512     512    1.0  RGB
# 2865            Calimerio/001497.jpg      jpg    512     512    1.0  RGB
# 4923           Hydrangeas/000030.jpg      jpg    512     512    1.0  RGB
# 12387                Tana/001201.jpg      jpg    512     512    1.0  RGB
# 6248   Hydrangeas/hydrangeas_243.jpg      jpg    512     512    1.0  RGB
# 9391             Pingpong/001510.jpg      jpg    512     512    1.0  RGB
# 4089        Chrysanthemum/001029.jpg      jpg    512     512    1.0  RGB
#
#        Bands  Transparency  Animated          Class
# 10022  R G B         False     False           Rosy
# 11756  R G B         False     False           Tana
# 12394  R G B         False     False           Tana
# 11387  R G B         False     False           Rosy
# 7551   R G B         False     False     Lisianthus
# 6202   R G B         False     False     Hydrangeas
# 5714   R G B         False     False     Hydrangeas
# 7990   R G B         False     False     Lisianthus
# 12896  R G B         False     False           Tana
# 3288   R G B         False     False  Chrysanthemum
# 749    R G B         False     False           Baby
# 10619  R G B         False     False           Rosy
# 3706   R G B         False     False  Chrysanthemum
# 7814   R G B         False     False     Lisianthus
# 4982   R G B         False     False     Hydrangeas
# 7923   R G B         False     False     Lisianthus
# 2264   R G B         False     False      Calimerio
# 7770   R G B         False     False     Lisianthus
# 10129  R G B         False     False           Rosy
# 7104   R G B         False     False     Lisianthus
# 5561   R G B         False     False     Hydrangeas
# 1217   R G B         False     False           Baby
# 4238   R G B         False     False  Chrysanthemum
# 11720  R G B         False     False           Tana
# 2201   R G B         False     False      Calimerio
# 12093  R G B         False     False           Tana
# 9609   R G B         False     False       Pingpong
# 7047   R G B         False     False     Lisianthus
# 7550   R G B         False     False     Lisianthus
# 1662   R G B         False     False           Baby
# 8992   R G B         False     False       Pingpong
# 7030   R G B         False     False     Lisianthus
# 99     R G B         False     False           Baby
# 9393   R G B         False     False       Pingpong
# 11535  R G B         False     False           Tana
# 12714  R G B         False     False           Tana
# 2865   R G B         False     False      Calimerio
# 4923   R G B         False     False     Hydrangeas
# 12387  R G B         False     False           Tana
# 6248   R G B         False     False     Hydrangeas
# 9391   R G B         False     False       Pingpong
# 4089   R G B         False     False  Chrysanthemum

# %%
train, val = train_test_split(df, shuffle=True, test_size=0.25, random_state=42)

print(f'Train data: {train.shape[0]} samples, Validation Data: {val.shape[0]} samples.')
# Out:
# Train data: 9804 samples, Validation Data: 3269 samples.

# %% [markdown]
# ## 3.2. Model Setup and Training

# %% [markdown]
# ### 3.2.1. Hyper-parameters

# %%
# Model Parameters
BATCH_SIZE = 512
INPUT_DIM = (TARGET_IMG_SIZE, TARGET_IMG_SIZE, 3)  # RGB - 3 channels images
HIDDEN_LAYER_DIM = 128
OUTPUT_CLASSES = 8  # One-hot encoded: 8 different classes

# Training Parameters
# EPOCHS = 32
EPOCHS = 2
LEARNING_RATE = 1e-6

# %% [markdown]
# ### 3.2.2. Model Architecture

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=INPUT_DIM),
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='relu'),
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='relu'),
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='relu'),
    tf.keras.layers.Dense(HIDDEN_LAYER_DIM, activation='sigmoid'),
    tf.keras.layers.Dense(OUTPUT_CLASSES),
], name=model_name)
model.summary()
# Out:
# Model: "clf-baseline"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 786432)            0
#
#  dense (Dense)               (None, 128)               100663424
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 100,713,992
# Trainable params: 100,713,992
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, to_file='images/BaselineModel-Diagram.png')

# %% [markdown]
# ### 3.2.3. Training

# %%
train['Class'] = train['Class'].astype('str')
train_datagen = ImageDataGenerator(data_format='channels_last')
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory=dir_train_dataset,
    x_col='ImgPath',
    y_col='Class',
    target_size=(TARGET_IMG_SIZE, TARGET_IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

val['Class'] = val['Class'].astype('str')
val_datagen = ImageDataGenerator(data_format='channels_last')
val_generator = val_datagen.flow_from_dataframe(
    dataframe=val,
    directory=dir_train_dataset,
    x_col='ImgPath',
    y_col='Class',
    target_size=(TARGET_IMG_SIZE, TARGET_IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)
# Out:
# Found 9804 validated image filenames belonging to 8 classes.
# Found 3269 validated image filenames belonging to 8 classes.

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=dir_log)

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['categorical_accuracy'],
)

history = model.fit(
    train_generator, validation_data=val_generator,
    epochs=EPOCHS,
    verbose=2, callbacks=[tensorboard_callback],
)
# Out:
# Epoch 1/2
# 20/20 - 101s - loss: 2.1392 - categorical_accuracy: 0.1401 - val_loss: 2.0886 - val_categorical_accuracy: 0.1496 - 101s/epoch - 5s/step
# Epoch 2/2
# 20/20 - 107s - loss: 2.0744 - categorical_accuracy: 0.1515 - val_loss: 2.0587 - val_categorical_accuracy: 0.1615 - 107s/epoch - 5s/step

# %%
plot_learning_curve(
    history.history['loss'],
    history.history['val_loss'],
    history.history['categorical_accuracy'],
    history.history['val_categorical_accuracy'],
    to_file='images/BaselineModel-LearningCurve.png'
)

# %% [markdown]
# ## 3.3. Performance
#
# Evaluated against test dataset in `./data/test/`

# %%
test = dataset.load(dir_test_dataset)
test['Class'] = test['Class'].astype('str')
test_datagen = ImageDataGenerator(data_format='channels_last')
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test,
    directory=dir_test_dataset,
    x_col='ImgPath',
    y_col='Class',
    target_size=(TARGET_IMG_SIZE, TARGET_IMG_SIZE),
    batch_size=1,
    class_mode='categorical',
    seed=42
)

model.evaluate(test_generator)
# Out:
# Found 3271 validated image filenames belonging to 8 classes.
# 3271/3271 [==============================] - 123s 38ms/step - loss: 2.0534 - categorical_accuracy: 0.1532
# [2.0533554553985596, 0.15316416323184967]

# %%
visualize_predictions(model, test_generator, to_file='images/BaselineModel-SamplePredictions.png')

# %% [markdown]
# ## 3.4. Exporting

# %%
if not os.path.exists(dir_models):
        os.makedirs(dir_models)

tf.keras.saving.save_model(
    model,
    open(path_model, 'wb'),
    overwrite=True,
    save_format='tf'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       1 if not os.path.exists(dir_models):
#       2         os.makedirs(dir_models)
# ----> 4 tf.keras.saving.save_model(
#       5     model,
#       6     open(path_model, 'wb'),
#       7     overwrite=True,
#       8     save_format='tf'
#       9 )
#
# File ~\Projects\rmit\cosc2753\rmit2023a-cosc2753-assignment2\venv\Lib\site-packages\keras\saving\saving_api.py:145, in save_model(model, filepath, overwrite, save_format, **kwargs)
#     142     saving_lib.save_model(model, filepath)
#     143 else:
#     144     # Legacy case
# --> 145     return legacy_sm_saving_lib.save_model(
#     146         model,
#     147         filepath,
#     148         overwrite=overwrite,
#     149         save_format=save_format,
#     150         **kwargs,
#     151     )
#
# File ~\Projects\rmit\cosc2753\rmit2023a-cosc2753-assignment2\venv\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\Projects\rmit\cosc2753\rmit2023a-cosc2753-assignment2\venv\Lib\site-packages\keras\saving\legacy\saving_utils.py:368, in is_hdf5_filepath(filepath)
#     366 def is_hdf5_filepath(filepath):
#     367     return (
# --> 368         filepath.endswith(".h5")
#     369         or filepath.endswith(".keras")
#     370         or filepath.endswith(".hdf5")
#     371     )
#
# AttributeError: '_io.BufferedWriter' object has no attribute 'endswith'
